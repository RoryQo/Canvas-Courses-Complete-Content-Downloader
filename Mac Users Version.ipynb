# %% [markdown]
# # Automated Canvas Course Content Downloader
#
# This script downloads all course materials from both current and past Canvas courses using the Canvas API. It supports all file types, including `.pdf`, `.R`, `.Rmd`, `.csv`, `.ipynb`, and others. Files embedded inside pages, modules, or viewer-style links are automatically identified and downloaded.
#
# ## Setup and Usage
#
# To run this script, follow these steps:
#
# 1. **Install Required Python Packages**
#    Use pip to install the following packages:
#
#    - `requests`
#    - `beautifulsoup4`
#    - `pdfkit`
#
# <br>
#
# 2. **Install `wkhtmltopdf`**
#    This tool is required by `pdfkit` to convert HTML content (pages, assignments, modules) into PDF files.
#    - Download and install it from: [https://wkhtmltopdf.org/downloads.html](https://wkhtmltopdf.org/downloads.html)
#    - Default path after installation will work.
#
# 3. **Generate and Add Your Canvas API Token**
#    - Log into Canvas, go to **Account > Settings > Approved Integrations**, and generate a new token.
#    - Paste it into the script where indicated (`API_TOKEN = '...'`).
#    - Replace `pitt` in canvas domain with your institutions canvas domain.
#
# 4. **Run the Script**
#    Open the notebook or Python script and run it. It will:
#    - Retrieve both active and completed Canvas courses
#    - Download all available files, linked content, and assignment submissions
#    - Convert Canvas-hosted HTML content into PDFs (no `.html` files are saved)
#    - Save everything to a structured local folder organized by course
#
# ## Output
#
# All downloaded files are saved to a local directory named `canvas_all_content`, with one subfolder per course. Original filenames and extensions are preserved
#
#
# ### Folder Structure
#
# ```
# canvas_all_content/
# ├── Course Name A/
# │   ├── lecture1.pdf
# │   ├── page - Syllabus.html
# │   ├── assignment - Essay.html
# │   ├── module - Week 1 Overview.html
# │   └── submission - final_essay.pdf
# ├── Course Name B/
# │   └── ...
# ```
#
# ### Notes
#
# - Most module and assignment PDFs may appear blank. This is expected behavior:
#   - Modules are often used as containers for linked content rather than standalone descriptions.
#   - Assignment pages are also frequently blank unless the instructor specifically writes assignment details in the Canvas page itself.
#   - These files are still processed because they often contain embedded links to downloadable materials.

# %%
# Ensure pdfkit is installed in the correct environment

# !/opt/miniconda3/envs/ba2/bin/python -m pip install pdfkit
# Out:
# Collecting pdfkit
#   Using cached pdfkit-1.0.0-py3-none-any.whl.metadata (9.3 kB)
# Using cached pdfkit-1.0.0-py3-none-any.whl (12 kB)
# Installing collected packages: pdfkit
# Successfully installed pdfkit-1.0.0

# %%
import os
import re
import requests
import pdfkit
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
# Check to see the path wkhtmltopdf is installed with (if needed)

    # import shutil

    # wkhtmltopdf_path = shutil.which('wkhtmltopdf')
    # print(wkhtmltopdf_path)
# Out:
# /usr/local/bin/wkhtmltopdf

# %%
# Configuration for wkhtmltopdf (change this path if needed)

# Corrected macOS path to wkhtmltopdf
pdfkit_config = pdfkit.configuration(wkhtmltopdf='/usr/local/bin/wkhtmltopdf')

# Fill in your details
API_TOKEN = 'Your_API_Key'
CANVAS_DOMAIN = 'https://canvas.pitt.edu'
BASE_API_URL = f'{CANVAS_DOMAIN}/api/v1'
DOWNLOADS_BASE = os.path.join(os.path.expanduser("~"), "Downloads", "canvas_all_content")
HEADERS = {'Authorization': f'Bearer {API_TOKEN}'}

# %%
downloaded_file_urls = set()

def make_safe(name):
    return re.sub(r'[<>:"/\\|?*]', '_', name).strip()

def safe_paginate(url):
    results = []
    try:
        while url:
            r = requests.get(url, headers=HEADERS)
            if r.status_code in [403, 404]:
                print(f"    Skipping ({r.status_code} error): {url}")
                return []
            r.raise_for_status()
            results.extend(r.json())
            url = r.links.get('next', {}).get('url')
        return results
    except Exception as e:
        print(f"    Error during pagination: {e}")
        return []

def save_html_as_pdf(folder, name, html_content):
    safe_name = make_safe(name)
    pdf_path = os.path.join(folder, f"{safe_name}.pdf")
    try:
        pdfkit.from_string(html_content, pdf_path, configuration=pdfkit_config)
        print(f"    Saved PDF: {safe_name}.pdf")
    except Exception as e:
        print(f"    Error converting {safe_name} to PDF: {e}")

def download_canvas_file_by_id(file_id, course_folder):
    try:
        meta = requests.get(f"{BASE_API_URL}/files/{file_id}", headers=HEADERS)
        meta.raise_for_status()
        file_data = meta.json()
        download_url = file_data['url']
        filename = make_safe(file_data['display_name'])

        if download_url in downloaded_file_urls:
            return

        r = requests.get(download_url, headers=HEADERS)
        r.raise_for_status()
        with open(os.path.join(course_folder, filename), 'wb') as f:
            f.write(r.content)

        downloaded_file_urls.add(download_url)
        print(f"    ✅ Downloaded file from API: {filename}")
    except Exception as e:
        print(f"    ❌ Error downloading file ID {file_id}: {e}")

def extract_and_download_linked_files(html, course_folder):
    soup = BeautifulSoup(html, 'html.parser')

    for tag in soup.find_all(['a', 'iframe'], href=True) + soup.find_all(['a', 'iframe'], src=True):
        href = tag.get('href') or tag.get('src')
        if href:
            match = re.search(r'/files/(\d+)', href)
            if match:
                file_id = match.group(1)
                download_canvas_file_by_id(file_id, course_folder)

    for script in soup.find_all('script'):
        if script.string:
            matches = re.findall(r'/files/(\d+)', script.string)
            for file_id in set(matches):
                download_canvas_file_by_id(file_id, course_folder)

# === Main Workflow ===
print("Fetching your Canvas courses...")

current_courses = safe_paginate(f"{BASE_API_URL}/courses?per_page=100&enrollment_state=active")
completed_courses = safe_paginate(f"{BASE_API_URL}/courses?per_page=100&enrollment_state=completed")

courses = current_courses + completed_courses


for course in courses:
    course_id = course['id']
    course_name = make_safe(course.get('name') or f"course_{course_id}")
    print(f"\nCourse: {course_name}")
    course_folder = os.path.join(DOWNLOADS_BASE, course_name)
    os.makedirs(course_folder, exist_ok=True)

    print("  Downloading files...")
    for file in safe_paginate(f"{BASE_API_URL}/courses/{course_id}/files?per_page=100"):
        try:
            file_url = file['url']
            if file_url in downloaded_file_urls:
                continue
            r = requests.get(file_url, headers=HEADERS)
            r.raise_for_status()
            file_path = os.path.join(course_folder, make_safe(file['filename']))
            with open(file_path, 'wb') as f:
                f.write(r.content)
            downloaded_file_urls.add(file_url)
        except Exception as e:
            print(f"    Error downloading {file.get('filename', 'unknown')}: {e}")

    print("  Downloading pages...")
    for page in safe_paginate(f"{BASE_API_URL}/courses/{course_id}/pages?per_page=100"):
        try:
            detail = requests.get(f"{BASE_API_URL}/courses/{course_id}/pages/{page['url']}", headers=HEADERS)
            if detail.status_code in [403, 404]:
                continue
            detail.raise_for_status()
            body = detail.json().get('body', '')
            name = f"page - {page['title']}"
            extract_and_download_linked_files(body, course_folder)
            save_html_as_pdf(course_folder, name, body)
        except Exception as e:
            print(f"    Error handling page {page['title']}: {e}")

    print("  Downloading assignments...")
    for assignment in safe_paginate(f"{BASE_API_URL}/courses/{course_id}/assignments?per_page=100"):
        try:
            description_html = assignment.get('description', '')
            name = f"assignment - {assignment['name']}"
            extract_and_download_linked_files(description_html, course_folder)
            html = f"<h1>{assignment['name']}</h1><p>{description_html}</p>"
            save_html_as_pdf(course_folder, name, html)
        except Exception as e:
            print(f"    Error handling assignment {assignment['name']}: {e}")

    print("  Downloading modules...")
    for module in safe_paginate(f"{BASE_API_URL}/courses/{course_id}/modules?per_page=100"):
        try:
            content = f"<h1>{module['name']}</h1><ul>"
            items = safe_paginate(f"{BASE_API_URL}/courses/{course_id}/modules/{module['id']}/items?per_page=100")
            for item in items:
                content += f"<li>{item['title']} ({item['type']})</li>"

                if item['type'] == 'File' and 'content_id' in item:
                    download_canvas_file_by_id(item['content_id'], course_folder)

                elif 'html_url' in item:
                    html_url = item['html_url']
                    item_resp = requests.get(html_url, headers=HEADERS)
                    if item_resp.ok:
                        extract_and_download_linked_files(item_resp.text, course_folder)

                elif item.get('type') == 'Page' and 'page_url' in item:
                    page_api_url = f"{BASE_API_URL}/courses/{course_id}/pages/{item['page_url']}"
                    page_resp = requests.get(page_api_url, headers=HEADERS)
                    if page_resp.ok:
                        body = page_resp.json().get('body', '')
                        extract_and_download_linked_files(body, course_folder)

            content += "</ul>"
            name = f"module - {module['name']}"
            save_html_as_pdf(course_folder, name, content)
        except Exception as e:
            print(f"    Error saving module {module['name']}: {e}")

    print("  Downloading your submissions...")
    submissions = safe_paginate(f"{BASE_API_URL}/courses/{course_id}/students/submissions?per_page=100")
    for sub in submissions:
        for attachment in sub.get("attachments", []):
            try:
                file_url = attachment['url']
                if file_url in downloaded_file_urls:
                    continue
                filename = make_safe(f"submission - {attachment['filename']}")
                r = requests.get(file_url, headers=HEADERS)
                r.raise_for_status()
                with open(os.path.join(course_folder, filename), 'wb') as f:
                    f.write(r.content)
                downloaded_file_urls.add(file_url)
                print(f"    Downloaded submission: {filename}")
            except Exception as e:
                print(f"    Error downloading submission file: {e}")

print("\n✅ All course content downloaded to your Downloads/canvas_all_content folder.")
# Out:
# Fetching your Canvas courses...
#
# Course: AFRICANA
#   Downloading files...
#     Skipping (403 error): https://canvas.pitt.edu/api/v1/courses/289900/files?per_page=100
#   Downloading pages...
#     Skipping (404 error): https://canvas.pitt.edu/api/v1/courses/289900/pages?per_page=100
#   Downloading assignments...
#     Saved PDF: assignment - Participation & Attendance.pdf
#     Saved PDF: assignment - Roll Call Attendance.pdf
#     Saved PDF: assignment - Discussion Question (Beta Run).pdf
#     Saved PDF: assignment - Discussion Question #1.pdf
#     Saved PDF: assignment - Discussion Question #2.pdf
#     Saved PDF: assignment - Discussion Question #3.pdf
#     Saved PDF: assignment - Discussion Question #4.pdf
#     Saved PDF: assignment - Discussion Question #5.pdf
#     Saved PDF: assignment - Discussion Question #6.pdf
#     Saved PDF: assignment - Discussion Question #7.pdf
#     Saved PDF: assignment - Discussion Question #8.pdf
#     Saved PDF: assignment - Discussion Question #9.pdf
#     Saved PDF: assignment - Discussion Question #10.pdf
#     Saved PDF: assignment - Discussion Question #11.pdf
#     Saved PDF: assignment - Mid-Term Examination.pdf
#     Error handling assignment Final Examination: object of type 'NoneType' has no len()
#     Saved PDF: assignment - Hawkins-Blackman Symposium_ How Does Race Structure the Experiences of Black Athletes_.pdf
#     Saved PDF: assignment - Malcolm X Week_ Do the Right Thing Film Screening and Talkback.pdf
#     Saved PDF: assignment - Malcolm X Week_ Food Distribution at the Teenie Harris Center.pdf
#     Saved PDF: assignment - Malcolm X Week_ Keynote Lecture by Dr. Richard D. Benson II_ “Requiem for a Revolutionary_ The Life and Legacy of Malcolm X”.pdf
#     Saved PDF: assignment - Frick Pittsburgh_ Kara Walker_ Harper's Pictorial History of the Civil War (Annotated).pdf
#   Downloading modules...
#     ✅ Downloaded file from API: AFRCNA 0031 - Introduction to Africana Studies - Spring 2025.pdf
#     Saved PDF: module - Syllabus.pdf
#     ✅ Downloaded file from API: Driving Questions in Africana Studies.pdf
#     ✅ Downloaded file from API: A Note on Notetaking.pdf
#     Saved PDF: module - Helpful Tools.pdf
#     Saved PDF: module - Week 1 - Course Introduction.pdf
#     ✅ Downloaded file from API: Biondi - The Strike at San Francisco State.pdf
#     ✅ Downloaded file from API: The Meaning of African American Studies _ The New Yorker.pdf
#     ✅ Downloaded file from API: What is Africana Studies (2025).pptx
#     ✅ Downloaded file from API: Du Bois - Of Our Spiritual Strivings.pdf
#     ✅ Downloaded file from API: Trouillot - An Unthinkable History.pdf
#     ✅ Downloaded file from API: Creating a Field of Knowledge (2025).pdf
#     Saved PDF: module - Week 2 - Course Introduction (cont'd)_ What is Africana Studies_ _ Creating a Field of Knowledge.pdf
#     ✅ Downloaded file from API: Dyer - Gathering Place.pdf
#     ✅ Downloaded file from API: Mellon - Students Seize Computer Center to Force Change.pdf
#     ✅ Downloaded file from API: Porter and Dyer - Pitt BAS Chronology.pdf
#     ✅ Downloaded file from API: Oral history with Curtiss Porter.pdf
#     ✅ Downloaded file from API: Oral history with Jack L. Daniel.pdf
#     ✅ Downloaded file from API: Oral history with Joyce Ford Kareem.pdf
#     ✅ Downloaded file from API: Oral history with Francine Greer.pdf
#     ✅ Downloaded file from API: Oral history with Barbara Hayden.pdf
#     ✅ Downloaded file from API: Oral history with Lora Head Hubbard.pdf
#     Saved PDF: module - Week 3 - The Origins and Development of Africana Studies.pdf
#     ✅ Downloaded file from API: Smallwood - Turning African Captives Into Atlantic Commodities.pdf
#     ✅ Downloaded file from API: James - The Black Jacobins.pdf
#     ✅ Downloaded file from API: Nesbitt - The Idea of 1804.pdf
#     ✅ Downloaded file from API: Eddins - Freedom Politics, Pt. 1 (Guest Lecture).pdf
#     Saved PDF: module - Week 4 - Freedom Politics.pdf
#     ✅ Downloaded file from API: Baker - Bigger than a Hamburger.pdf
#     ✅ Downloaded file from API: King - Letter from a Birmingham Jail.pdf
#     ✅ Downloaded file from API: Ture and Hamilton - Black Power.pdf
#     ✅ Downloaded file from API: Davis - Are Prisons Obsolete.pdf
#     ✅ Downloaded file from API: Taylor - Black Awakening in Obama's America.pdf
#     ✅ Downloaded file from API: Freedom Politics U.S.A. (2025).pdf
#     Saved PDF: module - Week 5 - Freedom Politics U.S.A..pdf
#     ✅ Downloaded file from API: Combahee River Collective Statement.pdf
#     ✅ Downloaded file from API: Ward - Third World Women's Alliance.pdf
#     ✅ Downloaded file from API: Johnson - Quare studies or almost everything I know about queer studies I learned from my grandmother.pdf
#     ✅ Downloaded file from API: Cohen - Punks, Bulldaggers, and Welfare Queens.pdf
#     ✅ Downloaded file from API: Yearwood - Gender, Sexuality, Diaspora.pdf
#     Saved PDF: module - Week 6 - Gender, Sexuality, and Diaspora.pdf
#     ✅ Downloaded file from API: Floyd - Transformations.pdf
#     ✅ Downloaded file from API: Henry - Popular Music and Axé Embodiment.pdf
#     ✅ Downloaded file from API: Livermon - Representations of Sophiatown in Kwaito Music.pdf
#     ✅ Downloaded file from API: BEEKO -- BLACK PERFORMANCE AESTHETICS (PRESENTATION NOTES) - 2025.pdf
#     ✅ Downloaded file from API: Locke - The New Negro.pdf
#     ✅ Downloaded file from API: Schuyler - The Negro-Art Hokum.pdf
#     ✅ Downloaded file from API: Hughes - The Negro Artist and the Racial Mountain.pdf
#     ✅ Downloaded file from API: The Harlem Renaissance (2025).pdf
#     Saved PDF: module - Week 7 - Black Aesthetics and Expressive Cultures.pdf
#     ✅ Downloaded file from API: Rose - All Aboard the Night Train.pdf
#     ✅ Downloaded file from API: Tate - Hip-Hop Turns 30.pdf
#     ✅ Downloaded file from API: Hip-Hop Music and Cultures (2025).pdf
#     Saved PDF: module - Week 8 - Black Aesthetics and Expressive Cultures (cont'd).pdf
#     ✅ Downloaded file from API: A Complex Revolutionary_ Remembering the Multi-Dimensional Malcolm X by Richard D. Benson II _ NewBlackMan (in Exile).pdf
#     ✅ Downloaded file from API: RBenson MXBookChapter.pdf
#     Saved PDF: module - Week 9 - The Black Radical Tradition.pdf
#     ✅ Downloaded file from API: Wood - The Earliest Africans in North America.pdf
#     ✅ Downloaded file from API: Bonilla-Silva - Reflections About Race.pdf
#     ✅ Downloaded file from API: Africa and Latin America (2025).pdf
#     ✅ Downloaded file from API: Dubuisson - Colonial Ruptures in the Caribbean.pdf
#     Saved PDF: module - Week 10 - Africa and Latin America.pdf
#     ✅ Downloaded file from API: Temple - Critical Race Theory.pdf
#     ✅ Downloaded file from API: Higginbotham - Acknowledgements.pdf
#     ✅ Downloaded file from API: Higginbotham - Introduction.pdf
#     Saved PDF: module - Week 11 - Race and the Law.pdf
#     ✅ Downloaded file from API: Fapohunda - Race, Health Inequities, and Causal Frameworks, Pt. 1 (Guest Lecture).pdf
#     ✅ Downloaded file from API: Alang and Blackstock - Health Justice.pdf
#     ✅ Downloaded file from API: Alang et al. - Mechanisms Connecting Police Brutality and Intersectionality.pdf
#     Saved PDF: module - Week 12_ Race, Health Inequities, and Causal Frameworks.pdf
#     ✅ Downloaded file from API: Traditional Leaders and Development in African Societies.pdf
#     ✅ Downloaded file from API: Developmental States in Africa.pdf
#     ✅ Downloaded file from API: Aid donors  democracy and the developmental state in Ethiopia.pdf
#     ✅ Downloaded file from API: Kouadio - On the Coloniality of News Mobilities.pdf
#     ✅ Downloaded file from API: Bianchini et al - Remembering a Forgotten History.pdf
#     ✅ Downloaded file from API: Presnetation ( April 9 2025).pdf
#     Saved PDF: module - Week 13 - African Studies_ Contemporary Politics, Society, and Development.pdf
#     ✅ Downloaded file from API: Kanneh - Coming Home.pdf
#     ✅ Downloaded file from API: Cousins and Dodgson-Katiyo - Leaving Home.pdf
#     ✅ Downloaded file from API: Zeleza - Diaspora Dialogues.pdf
#     ✅ Downloaded file from API: Arthur - African Immigrants and Native Born Blacks.pdf
#     ✅ Downloaded file from API: Kalua - Homi Bhabha's Third Space.pdf
#     ✅ Downloaded file from API: Africana 0031 - TA Lecture.pdf
#     Saved PDF: module - Week 14_ The Past, Present, and Future of Africana Studies.pdf
#     Saved PDF: module - Week 15 - Course Wrap-Up.pdf
#   Downloading your submissions...
#     Downloaded submission: submission - _Do+The+Right+Thing_+A+Spike+Lee+Joint+Screening+.docx
#     Downloaded submission: submission - Reflection+of+Dr+Benson%27s+_Requiem+for+a+Revolutionary_+The+Life+and+Legacy+of+Malcom+X_.docx
#
# Course: Business Analytics 2
#   Downloading files...
#     Skipping (403 error): https://canvas.pitt.edu/api/v1/courses/267212/files?per_page=100
#   Downloading pages...
#     Skipping (404 error): https://canvas.pitt.edu/api/v1/courses/267212/pages?per_page=100
#   Downloading assignments...
#     ✅ Downloaded file from API: assign_1_start.ipynb
#     Saved PDF: assignment - Assignment #1.pdf
#     Saved PDF: assignment - Assignment #1 File Submission.pdf
#     ✅ Downloaded file from API: assign_2_start.ipynb
#     Saved PDF: assignment - Assignment #2.pdf
#     Saved PDF: assignment - Assignment #2 File Submission.pdf
#     ✅ Downloaded file from API: assign_3_start.ipynb
#     Saved PDF: assignment - Assignment #3.pdf
#     Saved PDF: assignment - Assignment #3 File Submission.pdf
#     ✅ Downloaded file from API: assign_4_plotnine_lab.ipynb
#     Saved PDF: assignment - Assignment #4.pdf
#     Saved PDF: assignment - Assignment #4 File Submission.pdf
#     Saved PDF: assignment - Assignment #5.pdf
#     Saved PDF: assignment - Assignment #6.pdf
#     ✅ Downloaded file from API: assign_7_start.ipynb
#     Saved PDF: assignment - Assignment #7.pdf
#     Saved PDF: assignment - Assignment #7 File Submission.pdf
#     Saved PDF: assignment - Pandas Extra Credit File Submission.pdf
#     ✅ Downloaded file from API: take_home_test_1_start.ipynb
#     Saved PDF: assignment - Take-home Test #1 (90 minute time limit; one attempt).pdf
#     Saved PDF: assignment - Take-Home Test #1 File Submission.pdf
#     ✅ Downloaded file from API: ba2_take_home_test_2_notebook.ipynb
#     Saved PDF: assignment - Take-Home Test #2.pdf
#     Error handling assignment In-Class Test: object of type 'NoneType' has no len()
#     Saved PDF: assignment - 2nd-Chance Test.pdf
#     Saved PDF: assignment - 2nd-Chance Test Scoring.pdf
#     ✅ Downloaded file from API: pandas_xc_start.ipynb
#     Saved PDF: assignment - Pandas Extra Credit Quiz.pdf
#   Downloading modules...
#     ✅ Downloaded file from API: syllabus_busqom0102_ba2_fa24_haney.pdf
#     Saved PDF: module - Syllabus and Textbook Information.pdf
#     Saved PDF: module - Office Hours, Recitations, TA Help and Email Help.pdf
#     ✅ Downloaded file from API: intro_to_ba2_course.html
#     ✅ Downloaded file from API: intro_to_ba2_course.pdf
#     ✅ Downloaded file from API: command_line_conda_and_jupyter.docx
#     Saved PDF: module - Week 1_ Intro to the Course, Python Virtual Environments, and Jupyter, 8_26 - 9_1.pdf
#     ✅ Downloaded file from API: active_coding_week2_start.ipynb
#     ✅ Downloaded file from API: active_coding_week2_day1.ipynb
#     ✅ Downloaded file from API: active_coding_week2_day2.ipynb
#     ✅ Downloaded file from API: assign_1_solutions.ipynb
#     Saved PDF: module - Week 2_ Pandas Fundamentals, 9_2 - 9_8.pdf
#     ✅ Downloaded file from API: pandas_wk_3_in_class.ipynb
#     ✅ Downloaded file from API: pandas_wk_3_in_class_completed.ipynb
#     ✅ Downloaded file from API: assign_2_solutions.ipynb
#     Saved PDF: module - Week 3_ Data Grouping and Aggregation with Pandas, 9_9 - 9_15.pdf
#     ✅ Downloaded file from API: pandas_3_practice_day_1_progress.ipynb
#     ✅ Downloaded file from API: pandas_3_practice_complete.ipynb
#     ✅ Downloaded file from API: assign_3_solutions.ipynb
